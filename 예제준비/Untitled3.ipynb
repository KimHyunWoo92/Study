# %%
import numpy as np
import pandas as pd

# %%
arr1 = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])

# %%
print(arr1.shape)
print(arr1.ndim)
print(arr1.size)
# Out:
# (2, 2, 2)
# 3
# 8

# %%
arr1[0][0][0]
# Out:
# 1

# %%
arr1 = [[1,2,3],[4,5,6]]
df1 = pd.DataFrame(arr1)

# %%
df1
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df2 = pd.DataFrame(arr1,columns=["번호","숫자","높이"])

# %%
df2
# Out:
#    번호  숫자  높이
# 0   1   2   3
# 1   4   5   6

# %%
data = {'A': [1, 2, 3], 'B': [4, 5, 6]}
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df1["A"].iloc[1]
# Out:
# 2

# %%
arr = np.random.randint(2,10,size=(2,3))
print(arr)
# Out:
# [[7 9 4]
#  [4 5 7]]

# %%
print(arr.dtype())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 print(arr.dtype())
#
# TypeError: 'numpy.dtypes.Int32DType' object is not callable

# %%
x = 100
y = 200
add = x+y
print("%d와 %d의 합은 %d입니다"%(x,y,add))
# Out:
# 100와 200의 합은 300입니다

# %%
a = "hello"
print(a[0:5])
# Out:
# hello

# %%
list1 = [1,2,3,4,5]

# %%
# Out:
# [1]
# [2]
# [3]
# [4]
# [5]
# []

# %%
n =5
for i in range(1,n+1):
    print(" "*(n-i)+"*"*(2*i-1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********
