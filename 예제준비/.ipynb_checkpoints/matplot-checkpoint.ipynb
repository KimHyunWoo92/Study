# %% [markdown]
# ### pandas
# - pannel data 판넬 데이터
# - 행과 열이 있는 데이터의 형태, 표와같은 형태의 구조
# -

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(8)
y = [5,2,3,6,8,7,5,7]

# %%
plt.plot(x,y, ls="--",color="y",marker="X",ms=10,mec="b",mfc="w")

# %%
plt.plot(x,y, ls="--",color="y",marker="$♥$",ms=10,mec="b",mfc="w")

# %%
x1 = np.arange(5)
y1 = np.array([[4,5,2,1,8],[2,6,9,3,4]])
plt.plot(x1, y1[0], label="Line 1")  # 첫 번째 선
plt.plot(x1, y1[1], label="Line 2")
plt.show()

# %%
from matplotlib import font_manager, rc

# %%
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()

# %%
rc("font",family=font_name)

# %%
data = pd.read_csv("./data/Traffic_Accident_2017.csv",encoding="euc-kr")

# %%
data
# Out:
#        발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 0     2017  2017010101   15  야간  일     1     2     1     0       0  ...
# 1     2017  2017010102   28  야간  일     1     1     0     0       0  ...
# 2     2017  2017010102   43  야간  일     1     2     0     1       0  ...
# 3     2017  2017010102   22  야간  일     1     1     0     0       0  ...
# 4     2017  2017010104   37  야간  일     1     1     0     0       0  ...
# ...    ...         ...  ...  .. ..   ...   ...   ...   ...     ...  ...
# 4060  2017  2017123118   10  야간  일     1     4     1     0       2  ...
# 4061  2017  2017123118   25  야간  일     1     1     0     0       0  ...
# 4062  2017  2017123119   55  야간  일     1     1     0     0       0  ...
# 4063  2017  2017123120   40  야간  일     1    11     1     9       0  ...
# 4064  2017  2017123123   15  야간  일     1     1     0     0       0  ...
#
#      도로형태_대분류   도로형태 당사자종별_1당_대분류  당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4065 entries, 0 to 4064
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   발생년           4065 non-null   int64
#  1   발생년월일시        4065 non-null   int64
#  2   발생분           4065 non-null   int64
#  3   주야            4065 non-null   object
#  4   요일            4065 non-null   object
#  5   사망자수          4065 non-null   int64
#  6   사상자수          4065 non-null   int64
#  7   중상자수          4065 non-null   int64
#  8   경상자수          4065 non-null   int64
#  9   부상신고자수        4065 non-null   int64
#  10  발생지시도         4065 non-null   object
#  11  발생지시군구        4065 non-null   object
#  12  사고유형_대분류      4065 non-null   object
#  13  사고유형_중분류      4065 non-null   object
#  14  사고유형          4065 non-null   object
#  15  법규위반_대분류      4065 non-null   object
#  16  법규위반          4065 non-null   object
#  17  도로형태_대분류      4065 non-null   object
# ...

# %%
temp = data["요일"].value_counts()
print(temp)
# Out:
# 요일
# 화    608
# 월    603
# 금    603
# 토    596
# 목    586
# 수    565
# 일    504
# Name: count, dtype: int64

# %%
# 리스트 사용 권장, 또는 딕셔너리를 통해 "월":0,"화":1 으로 정리한뒤 정
y = temp[["월","화","수","목","금","토","일"]]
y
# Out:
# 요일
# 월    603
# 화    608
# 수    565
# 목    586
# 금    603
# 토    596
# 일    504
# Name: count, dtype: int64

# %%
x = y.index
plt.bar(x,y)
plt.show()

# %%
x = y.index
plt.bar(x,y)
plt.xlabel("요일")
plt.ylabel("사고 건수").set_rotation(0)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4065 entries, 0 to 4064
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   발생년           4065 non-null   int64
#  1   발생년월일시        4065 non-null   int64
#  2   발생분           4065 non-null   int64
#  3   주야            4065 non-null   object
#  4   요일            4065 non-null   object
#  5   사망자수          4065 non-null   int64
#  6   사상자수          4065 non-null   int64
#  7   중상자수          4065 non-null   int64
#  8   경상자수          4065 non-null   int64
#  9   부상신고자수        4065 non-null   int64
#  10  발생지시도         4065 non-null   object
#  11  발생지시군구        4065 non-null   object
#  12  사고유형_대분류      4065 non-null   object
#  13  사고유형_중분류      4065 non-null   object
#  14  사고유형          4065 non-null   object
#  15  법규위반_대분류      4065 non-null   object
#  16  법규위반          4065 non-null   object
#  17  도로형태_대분류      4065 non-null   object
# ...

# %%
car = data[data["사고유형_대분류"]=="차대차"]
car
# Out:
#        발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 0     2017  2017010101   15  야간  일     1     2     1     0       0  ...
# 2     2017  2017010102   43  야간  일     1     2     0     1       0  ...
# 8     2017  2017010118   33  야간  일     1     3     1     1       0  ...
# 9     2017  2017010120    0  야간  일     1     7     4     2       0  ...
# 17    2017  2017010209    0  주간  월     1     2     1     0       0  ...
# ...    ...         ...  ...  .. ..   ...   ...   ...   ...     ...  ...
# 4050  2017  2017123009   58  주간  토     1     1     0     0       0  ...
# 4055  2017  2017123023   50  야간  토     1     6     2     3       0  ...
# 4058  2017  2017123112   10  주간  일     1     1     0     0       0  ...
# 4060  2017  2017123118   10  야간  일     1     4     1     0       2  ...
# 4063  2017  2017123120   40  야간  일     1    11     1     9       0  ...
#
#      도로형태_대분류   도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK  \
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1642 entries, 0 to 4063
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   발생년           1642 non-null   int64
#  1   발생년월일시        1642 non-null   int64
#  2   발생분           1642 non-null   int64
#  3   주야            1642 non-null   object
#  4   요일            1642 non-null   object
#  5   사망자수          1642 non-null   int64
#  6   사상자수          1642 non-null   int64
#  7   중상자수          1642 non-null   int64
#  8   경상자수          1642 non-null   int64
#  9   부상신고자수        1642 non-null   int64
#  10  발생지시도         1642 non-null   object
#  11  발생지시군구        1642 non-null   object
#  12  사고유형_대분류      1642 non-null   object
#  13  사고유형_중분류      1642 non-null   object
#  14  사고유형          1642 non-null   object
#  15  법규위반_대분류      1642 non-null   object
#  16  법규위반          1642 non-null   object
#  17  도로형태_대분류      1642 non-null   object
# ...

# %%
car[["사상자수","발생지시도"]]
# Out:
#       사상자수 발생지시도
# 0        2    전남
# 2        2    충남
# 8        3    제주
# 9        7    충남
# 17       2    경북
# ...    ...   ...
# 4050     1    경남
# 4055     6    광주
# 4058     1    경북
# 4060     4    경남
# 4063    11    경기
#
# [1642 rows x 2 columns]

# %%
np.unique(car["발생지시도"])
# Out:
# array(['강원', '경기', '경남', '경북', '광주', '대구', '대전', '부산', '서울', '세종', '울산',
#        '인천', '전남', '전북', '제주', '충남', '충북'], dtype=object)

# %%
car_place = car[["사상자수","발생지시도"]].groupby("발생지시도").sum()
car_place
# Out:
#        사상자수
# 발생지시도
# 강원      214
# 경기      824
# 경남      248
# 경북      287
# 광주       87
# 대구      115
# 대전       61
# 부산      107
# 서울      197
# 세종       17
# 울산       73
# 인천       66
# 전남      298
# 전북      244
# 제주       50
# 충남      351
# 충북      261

# %%
car_place1 = car.groupby("발생지시도")["사상자수"].sum()
car_place1
# Out:
# 발생지시도
# 강원    214
# 경기    824
# 경남    248
# 경북    287
# 광주     87
# 대구    115
# 대전     61
# 부산    107
# 서울    197
# 세종     17
# 울산     73
# 인천     66
# 전남    298
# 전북    244
# 제주     50
# 충남    351
# 충북    261
# Name: 사상자수, dtype: int64

# %%
car_place2 = car.groupby(["발생지시도"])[["사상자수","발생지시도"]].sum()
car_place2
# Out:
#        사상자수                                              발생지시도
# 발생지시도
# 강원      214  강원강원강원강원강원강원강원강원강원강원강원강원강원강원강원강원강원강원강원강원강원강원강원...
# 경기      824  경기경기경기경기경기경기경기경기경기경기경기경기경기경기경기경기경기경기경기경기경기경기경기...
# 경남      248  경남경남경남경남경남경남경남경남경남경남경남경남경남경남경남경남경남경남경남경남경남경남경남...
# 경북      287  경북경북경북경북경북경북경북경북경북경북경북경북경북경북경북경북경북경북경북경북경북경북경북...
# 광주       87  광주광주광주광주광주광주광주광주광주광주광주광주광주광주광주광주광주광주광주광주광주광주광주...
# 대구      115  대구대구대구대구대구대구대구대구대구대구대구대구대구대구대구대구대구대구대구대구대구대구대구...
# 대전       61  대전대전대전대전대전대전대전대전대전대전대전대전대전대전대전대전대전대전대전대전대전대전대전...
# 부산      107  부산부산부산부산부산부산부산부산부산부산부산부산부산부산부산부산부산부산부산부산부산부산부산...
# 서울      197  서울서울서울서울서울서울서울서울서울서울서울서울서울서울서울서울서울서울서울서울서울서울서울...
# 세종       17                               세종세종세종세종세종세종세종세종세종세종
# 울산       73  울산울산울산울산울산울산울산울산울산울산울산울산울산울산울산울산울산울산울산울산울산울산울산...
# 인천       66  인천인천인천인천인천인천인천인천인천인천인천인천인천인천인천인천인천인천인천인천인천인천인천...
# 전남      298  전남전남전남전남전남전남전남전남전남전남전남전남전남전남전남전남전남전남전남전남전남전남전남...
# 전북      244  전북전북전북전북전북전북전북전북전북전북전북전북전북전북전북전북전북전북전북전북전북전북전북...
# ...

# %%
car_place3 = car.groupby(["발생지시도"])["사상자수", "발생지시도"].sum()
car_place3.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 car_place3 = car.groupby(["발생지시도"])["사상자수", "발생지시도"].sum()
#       2 car_place3.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1960, in DataFrameGroupBy.__getitem__(self, key)
#    1956 # per GH 23566
#    1957 if isinstance(key, tuple) and len(key) > 1:
#    1958     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1959     # valid syntax, so don't raise
# -> 1960     raise ValueError(
#    1961         "Cannot subset columns with a tuple with more than one element. "
#    1962         "Use a list instead."
#    1963     )
#    1964 return super().__getitem__(key)
#
# ValueError: Cannot subset columns with a tuple with more than one element. Use a list instead.

# %%
print(car_place2.columns)
# Out:
# Index(['사상자수', '발생지시도'], dtype='object')

# %%
x = car_place.index
y = car_place.values

# %%
plt.figure(figsize=(15,8))
plt.plot(x,y)
plt.xlabel("지역")
plt.ylabel("사상자수").set_rotation(0)
plt.title("지역별 차 vs 차 교통사고 사상자")
plt.show()

# %%
y.shape
# Out:
# (17, 1)

# %%
y_bar = []
for i in range(len(y)):
    y_bar.append(y[i][0])

# %%
print(y_bar)
# Out:
# [214, 824, 248, 287, 87, 115, 61, 107, 197, 17, 73, 66, 298, 244, 50, 351, 261]

# %%
plt.figure(figsize=(15,8))
plt.bar(x,y)
plt.xlabel("지역")
plt.ylabel("사상자 수").set_rotation(0)
plt.title("차 vs 차 교통사고의 사상자 수")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 plt.figure(figsize=(15,8))
# ----> 2 plt.bar(x,y)
#       3 plt.xlabel("지역")
#       4 plt.ylabel("사상자 수").set_rotation(0)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2742, in bar(x, height, width, bottom, align, data, **kwargs)
#    2731 @_copy_docstring_and_deprecators(Axes.bar)
#    2732 def bar(
#    2733     x: float | ArrayLike,
#    (...)
#    2740     **kwargs,
#    2741 ) -> BarContainer:
# -> 2742     return gca().bar(
#    2743         x,
#    2744         height,
#    2745         width=width,
#    2746         bottom=bottom,
#    2747         align=align,
#    2748         **({"data": data} if data is not None else {}),
#    2749         **kwargs,
#    2750     )
#
# ...

# %%
plt.figure(figsize=(15,8))
plt.bar(x,y_bar)
plt.xlabel("지역")
plt.ylabel("사상자 수").set_rotation(0)
plt.title("차 vs 차 교통사고의 사상자 수")
plt.show()

# %%
time = data["발생년월일시"].astype("int64")
time %= 100
time
# Out:
# 0        1
# 1        2
# 2        2
# 3        2
# 4        4
#         ..
# 4060    18
# 4061    18
# 4062    19
# 4063    20
# 4064    23
# Name: 발생년월일시, Length: 4065, dtype: int64

# %%
bins = [-1, 2, 5, 8, 11, 14, 17, 20, 23]
labels = ["0~2", "3~5", "6~8", "9~11", "12~14", "15~17", "18~20", "21~23"]

result = pd.cut(time, bins, labels=labels)
result
# Out:
# 0         0~2
# 1         0~2
# 2         0~2
# 3         0~2
# 4         3~5
#         ...
# 4060    18~20
# 4061    18~20
# 4062    18~20
# 4063    18~20
# 4064    21~23
# Name: 발생년월일시, Length: 4065, dtype: category
# Categories (8, object): ['0~2' < '3~5' < '6~8' < '9~11' < '12~14' < '15~17' < '18~20' < '21~23']

# %%
rs_data = result.value_counts().sort_index()
plt.figure(figsize=(5,5))
plt.pie(rs_data,labels=labels,autopct="%1.1f%%")
plt.show()
