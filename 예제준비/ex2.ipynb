# %%
num1 = 10
str2 = "7"
str3 = "hello"
str4 = "안녕하세요 \n오늘 수업은 연산자에 대해 배워볼거에요"
print(str(num1)+str2)
print(str2)
print("7")
print(str3)
print("hello")

# %%
x = 100
y = 200
add = x+y
print("%d와 %d의 합은 %d입니다"%(x,y,add))
# Out:
# 100와 200의 합은 300입니다

# %%
x = 300
y = 100
minus = x-y
print("{}와{}의 차는 {}입니다.".format(x,y,minus))
# Out:
# 300와100의 차는 200입니다.

# %%
x = 300
y = 100
minus = x-y
print("{2}와{0}의 차는 {1}입니다.".format(y,minus,x))
# Out:
# 300와100의 차는 200입니다.

# %%
x = 50
y = 20
multi = x*y
print(f"{x}와{y}의 곱은 {multi}입니다.")
# Out:
# 50와20의 곱은 1000입니다.

# %%
str4 = "안녕하세요 \n오늘 수업은 연산자에 대해 배워볼거에요"
str4
# Out:
# '안녕하세요 \n오늘 수업은 연산자에 대해 배워볼거에요'

# %%
# 예제
str3
# Out:
# 'hello'

# %%
print(str4)
# Out:
# 안녕하세요
# 오늘 수업은 연산자에 대해 배워볼거에요

# %%
print(str2)
str2
# Out:
# 7
# '7'

# %%
num2 = input()
# Out:
#  10,20,30

# %%
print(num2[:])
# Out:
# 10,20,30

# %%
import sys

# %%
print("입력된 데이터: \nPython\nis\n awesome")
data = sys.stdin.read()
print(data)
# Out:
# 입력된 데이터:
# Python
# is
#  awesome

# %%
score1 = int(input("언어 점수 입력 >>"))
score2 = int(input("수리 점수 입력 >>"))
score3 = int(input("외국어 점수 입력 >>"))
num = score1+score2+score3
print("합계 : {}".format(num))
print("평균 : {}".format((score1+score2+score3)/3))
# Out:
# 언어 점수 입력 >> 100
# 수리 점수 입력 >> 80
# 외국어 점수 입력 >> 60
# 합계 : 240
# 평균 : 80.0

# %%
num1 =23
num2 = 3
print("더하기 결과 :",num1+num2)
print("빼기 결과 :",num1-num2)
# Out:
# 더하기 결과 : 26

# %%
time = int(input("시간 입력 >>"))
# 1분 = 60초
# 1시간 = 60분 = 3600초
hour = time//3600
minute = (time%3600)//60
second = time%60
print(f"{hour}시간 {minute}분 {second}초")
# Out:
# 0
# 0시간 18분 43초

# %%
num = 3
num +=3 
print(num)
# Out:
# 6

# %%
score = 80
"합격" if score>= 60 and score<=100 else "불합격"
# Out:
# '합격'

# %%
print("뱅"*3)
# Out:
# 뱅뱅뱅

# %%
num1 = 10
str2 = "7"
print(num1+str2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 num1 = 10
#       2 str2 = "7"
# ----> 3 print(num1+str2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
num1 = 23
str1 = "11"
?
# Out:
# 더하기 결과 :  34
# 빼기 결과 :  12
# 곱하기 결과 :  253
# 나누기 결과 :  2.090909090909091
# 2311번 고객님

# %%
print(10+"2.5")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(10+"2.5")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(10+int("3.0"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(10+int("3.0"))
#
# ValueError: invalid literal for int() with base 10: '3.0'

# %%
print(10+int(float("3.0")))
# Out:
# 13

# %%
int(12.3)
# Out:
# 12

# %%
num1 = 3
num2 = 3.5
num3 = num1+num2
print(num3)
# Out:
# 6.5

# %%
num1 = 30
num2 = 12
print(?)
print(?)
print(?)
print(?.format(num1,num2,(num1/num2)))
# Out:
# 30와 12의 합은 : 42
# 12와 30의 차는 : -18
# 360은 30와 12의 곱이다
# 2.5은 30와 12을 나눈 값이다

# %%
str1 = "Python"
str2 = "은 프로그래밍 언어이다."
str3 = "오늘은 연산자를 배우고 있다."
print(?)
print(f"?")
# Out:
# Python은 프로그래밍 언어이다.
# Python은 프로그래밍 언어이다. 오늘은 연산자를 배우고 있다.

# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %%
a =10
b = 5
print(a>b)
# Out:
# True

# %%
a =int("3")
b = float("3.000")
print(a==b)
# Out:
# True

# %%
age = 16

# %%
if age >= 18:
    print("성인입니다.")
    print("술을 살 수 있습니다.")
print("프로그램 종료")
# Out:
# 성인입니다.
# 술을 살 수 있습니다.
# 프로그램 종료

# %%
if age >=20:
# Out:
# 성인입니다
# 술을 살 수 있습니다.

# %%
if True:
    print("실행문장")
    print("공백은 4칸")
# Out:
# 실행문장
# 공백은 4칸

# %%
if True:
  print("실행문장")
  print("공백이 2칸??")
# Out:
# 실행문장
# 공백이 2칸??

# %%
# Out:
#   File <tokenize>:3
#     print("공백이2칸??")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
money = 10000
if money >= 10000:
    print("택시를탄다")
# Out:
# 택시를탄다

# %%
money = 9000
if money >= 10000:
    print("택시를 탄다")

# %%
age = 20
"성인" if age>=20 else "미성년자"
# Out:
# '성인'

# %%
age = 18
if age >= 20:
    print("성인입니다.")
else:
    print("미성년자입니다.")
# Out:
# 미성년자입니다.

# %%
age = 18
status = "성인" if age>=20 else "미성년자"
print(status)
# Out:
# 미성년자

# %%
age = 25
support = "청년 지원 대상입니다." if 39>=age>=18 else "청소년 지원대상이 아닙니다."
print(support)
# Out:
# 청년 지원 대상입니다.

# %%
age = 10
if 39>= age >= 18:
    print("청년 지원대상입니다.")
else:
    print("청소년 지원대상이 아닙니다.")
# Out:
# 청소년 지원대상이 아닙니다.

# %%
gift = 10000
buy = int(input("사려는 상품의 갯수를 입력하세요>>"))
if buy>=11:
    price = (buy*gift*9)//10
    print(f"가격은 {price}원 입니다")
else:
    print(f"가격은 {price}원 입니다")
# Out:
# 가격은 108000원 입니다

# %%
gift = 10000
buy = int(input("사려는 상품의 갯수를 입력하세요>>"))
if buy>=11:
    price = (buy*gift*9)//10
    print(f"가격은 {price}원 입니다")
else:
    print(f"가격은 {price}원 입니다")
# Out:
# 사려는 상품의 갯수를 입력하세요>> 9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5     print(f"가격은 {price}원 입니다")
#       6 else:
# ----> 7     print(f"가격은 {price}원 입니다")
#
# NameError: name 'price' is not defined

# %%
# 20살미만 미성년자
# 20살이상 성인
# 65살이상 고령

age = 65
if age < 20:
    print("미성년자")
elif age >=65:
    print("고령")
elif age >= 20:
    print("성인")
# Out:
# 고령

# %%
score = int(input("점수를 입력하세요>>"))

if 100>= score >=90:
    print(f"{score}점은 A학점 입니다.")
elif 90 > score >= 80:
    print(f"{score}점은 B학점 입니다.")
elif 80 > score >= 70:
    print(f"{score}점은 c학점 입니다.")
elif 70 > score >= 60:
    print(f"{score}점은 d학점 입니다.")
else:
    print(f"{score}점은 f학점 입니다.")
# Out:
# 점수를 입력하세요>> 101
# 101점은 f학점 입니다.

# %%
score = int(input("점수를 입력하세요"))
if score > 100 or score <0:
    print("점수를 잘못입력하였습니다.")
elif score >=90:
    print(f"{score}점은 A학점 입니다.")
elif score >= 80:
    print(f"{score}점은 B학점 입니다.")
elif score >= 70:
    print(f"{score}점은 c학점 입니다.")
elif score >= 60:
    print(f"{score}점은 d학점 입니다.")
else:
    print(f"{score}점은 f학점 입니다.")
# Out:
# 점수를 입력하세요 105
# 점수를 잘못입력하였습니다.

# %%
print('''
===================================
===============자판기===============
==1.콜라==2.사이다==3.물 ====insert==
==--------=======-----=======----===
== 600 == 800 == 1000 ======000원===
====================================
''')
in_coin = int(input("insert coin >>"))
select_menu = input("메뉴 선택 >>")

if select_menu == "1":
    if in_coin < 600:
        print("잔액부족")
    else:
        pay_back = in_coin - 600
        print(f"1000원 {pay_back//1000}개, 500원 {(pay_back%1000)//500}개, 100원 {((pay_back%1000)%500)//100}개")
elif select_menu == "2":
    if in_coin < 800:
        print("잔액부족")
    else:
        pay_back = in_coin - 800
        
        thousand = pay_back//1000
        pay_back %= 1000

        five_hundred = pay_back//500
        pay_back %= 500

        hundred = pay_back//100
        pay_back %=100
        
        print(f"잔돈 >> 1000원 {thousand}개, 500원 {five_hundred}개, 100원 {hundred}개")
elif select_menu == "3":
    pass
else:
    print("메뉴를 다시 선택해주세요")
# Out:
# ...
# ===============자판기===============
# ==1.콜라==2.사이다==3.물 ====insert==
# ==--------=======-----=======----===
# == 600 == 800 == 1000 ======000원===
# ...
# insert coin >> 5000
# 메뉴 선택 >> 2
# 잔돈 >> 1000원 4개, 500원 0개, 100원 2개

# %%
list6 = [0,1,2,3,4]
print("수정전 : ",list6)
list6[1]=7
print("수정후 : ",list6)
# Out:
# 수정전 :  [0, 1, 2, 3, 4]
# 수정후 :  [0, 7, 2, 3, 4]

# %%
print(list6[2:4],list6[2:3])
list6[2:4]=7
print(list6)
# Out:
# [2, 3] [2]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 print(list6[2:4],list6[2:3])
# ----> 2 list6[2:4]=7
#       3 print(list6)
#
# TypeError: can only assign an iterable

# %%
list3 = [0,1,2,3,4]
list3[1:3]
# Out:
# [0, 1, 2, 3, 4]

# %%
a = list("123")

# %%
print(a)
# Out:
# ['1', '2', '3']

# %%
list = [1,2,3,"hello","my","name"]
print(list)
# Out:
# [1, 2, 3, 'hello', 'my', 'name']

# %%
num1 = 1,2
print(num1)
# Out:
# (1, 2)

# %%
a,b = 1,2,3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 a,b = 1,2,3
#
# ValueError: too many values to unpack (expected 2)

# %%
list = [1,2,2,4,5,6]
list[?] = 3
print(list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
my_list = [10,20,"30",40,"50"]
print(?)
print("두값의 차는 : ", ?))
print(my_list[?])
# Out:
# 20
# 두값의 차는 :  10
# [20, '30', 40, '50']

# %%
print(my_list[1:10])
# Out:
# [20, '30', 40, '50']

# %%
my_list[1:10]
# Out:
# [20, '30', 40, '50']

# %%
list1 = []
n = 10
k= 3
for i in range(1,n+1):
    if i%3 == 0:
        list1.append(i)
print(list1)
# Out:
# [3, 6, 9]

# %%
list2 = []
num1 = [5,1,4]
for num in num1:
    for i in range(num):
        list2.append(num)

print(list2)
# Out:
# [5, 5, 5, 5, 5, 1, 4, 4, 4, 4]
