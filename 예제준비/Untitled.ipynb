# %%
dic1 = {}
dic2 = {"name":"HY"}

# %%
print(type(dic1))
# Out:
# <class 'dict'>

# %%
dic1["age"] = 20

# %%
dic1["age"] = [20,30]

# %%
print(dic1.get("age"))
# Out:
# [20, 30]

# %%
dic1 = [1,3,4]
dic2 = {"num1":1}

# %%
dic1
# Out:
# [1, 3, 4]

# %%
dic1.insert(1,2)
dic1
# Out:
# [1, 2, 3, 4]

# %%
dic2[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dic2[0]
#
# KeyError: 0

# %%
dic1
# Out:
# [1, 2, 3, 4]

# %%
dic1[4] = 5
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dic1[4] = 5
#
# IndexError: list assignment index out of range

# %%
dic2["num1"] = [20,30]
dic2
# Out:
# {'num1': [20, 30], 'name': 'HY'}

# %%
print(dic2)
dic2["name"] = "HY"
print(dic2)
# Out:
# {'num1': [15, 30], 'name': 'MY'}
# {'num1': [15, 30], 'name': 'HY'}

# %%
# Out:
# {'num1': [15, 30], 'name': 'MY'}

# %%
dic1.append(5)
print(dic1)
# Out:
# [1, 2, 3, 4, 5]

# %%
dic2.get()
# Out:
# None

# %%
score_dic = {"홍길동":{"수학":99,"영어":80,"국어":75},
             "김미정":{"영어":67,"국어":87,"수학":55},
             "정수진":{"수학":67,"국어":41,"영어":23}}

# %%
score_dic.keys()
# Out:
# dict_keys(['홍길동', '김미정', '정수진'])

# %%
result = {"수학":0,"영어":0,"국어":0}
math = 0
korean = 0
english = 0

# %%
result = {"수학":0,"영어":0,"국어":0}
# math = 0
# korean = 0
# english = 0
for items in score_dic.values():
    print(items)
    result["수학"] += items["수학"]
    result["국어"] += items["국어"]
    result["영어"] += items["영어"]
    # result["수학"] = math
    # result["국어"] = korean
    # result["영어"] = english
    print(result)
# print(math,korean,english)
# Out:
# {'수학': 99, '영어': 80, '국어': 75}
# {'수학': 99, '영어': 80, '국어': 75}
# {'영어': 67, '국어': 87, '수학': 55}
# {'수학': 154, '영어': 147, '국어': 162}
# {'수학': 67, '국어': 41, '영어': 23}
# {'수학': 221, '영어': 170, '국어': 203}

# %%
dic3 = {"name":"hy","age":30,"phoe":"010-1234-1234"}
print(dic3.keys())
# Out:
# <class 'list'>

# %%
dic3.clear()

# %%
key = ["name","age","phone"]
info = ["HY",30,"010-1234-5678"]

# 코드 작성

print(my_info)
# Out:
# {'name': 'HY', 'age': 30, 'phone': '010-1234-5678'}

# %%
print(dic4)
# Out:
# {'name': 'HY', 'age': 30, 'phone': '010-1234-5678'}

# %%
if "birth" not in dic4:
    dic4["birth"] = "12/31"
print(dic4)
# Out:
# {'name': 'HY', 'age': 30, 'phone': '010-1234-5678', 'birth': '12/31'}

# %%
dic2 = {"name":"MH","age":20,"phone":"010-1234-1234"}

# %%
"name" in dic2
# Out:
# True

# %%
"성별" in dic2
# Out:
# False

# %%
"MH" in dic2
# Out:
# False

# %%
test_dic2 = ["name","age","phone","birth"]
for i in test_dic2:
    if i in dic2:
        print("키값이 존재합니다.")
    else:
        dic2[i] = "12/31"
        print("키값을 추가하")

print(dic2)
# Out:
# 키값이 존재합니다.
# 키값이 존재합니다.
# 키값이 존재합니다.
# {'name': 'MH', 'age': 20, 'phone': '010-1234-1234', 'birth': '12/31'}
