# %%
s = "월 스미스가 하드캐리ㅋㅋㅋㅋㅋㅋㅋㅋ"
s.replace("ㅋ","")
# Out:
# '월 스미스가 하드캐리'

# %%
def number_sum(num1,num2):
    result = num1+num2
    return result

# %%
number_sum()

# %%
def add(*args):
    length = len(args)
    result = 0
    for i in range(length):
        result += args[i]
    return result

# %%
add(1,2,3)
# Out:
# 6

# %%
a = "hello"

# %%
b = "world"
"hello {}".format(b)
# Out:
# 'hello world'

# %%
dict()
