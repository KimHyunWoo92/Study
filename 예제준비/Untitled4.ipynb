# %%
import numpy as np

# %%
a = np.array(1)

# %%
print(a.dtype)
# Out:
# int32

# %%
arr1 = np.array([1, 2, 3])  # shape (3,)
arr2 = np.array([[10], [20], [30]])  # shape (3,1)

print(arr1 + arr2)  # (1,3) + (3,1) -> (3,3)
# Out:
# [[11 12 13]
#  [21 22 23]
#  [31 32 33]]
