# %%
import requests as req

# %%
req.get("https://www.naver.com")
# Out:
# <Response [200]>

# %%
res = req.get("https://www.naver.com")
res.text
# Out:
# '   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description
# ...

# %%
from bs4 import BeautifulSoup as bs

# %%
soup = bs(res.text,"lxml")

# %%
print(type(res.text),type(soup))
# Out:
# <class 'str'> <class 'bs4.BeautifulSoup'>

# %%
res = req.get("https://news.daum.net/")

# %%
res.status_code
# Out:
# 200

# %%
soup = bs(res.text,"lxml")

# %%
title = soup.select("a div strong.tit_txt")
len(title)
# Out:
# 39

# %%
title[0].text
# Out:
# 'ï§¡ë\x8c\x80í\x86µë\xa0¹ "ì\x9e¬ì\x97°ì\x9e¥ ì\x83\x9dê°\x81í\x96\x88ë\x8b¤ë©´ ì\x98¤ì\x82°"â\x80¦ì\x96\x91ë\x8f\x84ì\x84¸ì¤\x91ê³¼ ì\x9c\xa0ì\x98\x88ì¢\x85ë£\x8c ì\x9e¬ê°\x95ì¡°(ì¢\x85í\x95©)'

# %%
res.encoding = "utf-8"

# %%
print(res.headers)
print(res.headers.get("Content-Type"))
# Out:
# {'Date': 'Sun, 25 Jan 2026 16:08:51 GMT', 'Content-Type': 'text/html', 'Content-Length': '102224', 'Connection': 'keep-alive', 'Vary': 'Origin, Access-Control-Request-Method, Access-Control-Request-Headers', 'X-Powered-By': 'Express', 'Access-Control-Allow-Origin': '*', 'link': '<https://t1.daumcdn.net/top/tiller-pc/modoo-web/production/20251217111702/_app/immutable/entry/start.CaOvQ6pI.js>; rel="modulepreload"; nopush, <https://t1.daumcdn.net/top/tiller-pc/modoo-web/production/20251217111702/_app/immutable/chunks/2.Da1EST6i.js>; rel="modulepreload"; nopush, <https://t1.daumcdn.net/top/tiller-pc/modoo-web/production/20251217111702/_app/immutable/chunks/scheduler.DX5Ay67z.js>; rel="modulepreload"; nopush, <https://t1.daumcdn.net/top/tiller-pc/modoo-web/production/20251217111702/_app/immutable/entry/app.C2S793vD.js>; rel="modulepreload"; nopush, <https://t1.daumcdn.net/top/tiller-pc/modoo-web/production/20251217111702/_app/immutable/chunks/matrix.DpX0cMMg.js>; rel="modulepreload"; nopu
# ...

# %%
soup = bs(res.text,"lxml")
title = soup.select("a div strong.tit_txt")

# %%
len(title)
# Out:
# 39

# %%
title
# Out:
# [<strong class="tit_txt">李대통령 "재연장 생각했다면 오산"…양도세중과 유예종료 재강조(종합)</strong>,
#  <strong class="tit_txt">金 5000달러 눈앞, 銀 100달러 돌파… 동반 최고치 행진</strong>,
#  <strong class="tit_txt">[그린란드를 가다] 트럼프 야욕에 심란한데 대규모 정전까지(종합)</strong>,
#  <strong class="tit_txt">주말에도 김병기 의혹 집중 수사...소환 시기 관심</strong>,
#  <strong class="tit_txt">4번의 민주정부 수립 함께한 ‘전략가’이자 ‘킹메이커’…이해찬 전 총리 별세</strong>,
#  <strong class="tit_txt">'독기' 더 빼는 소주 [어떻게 생각하십니까]</strong>,
#  <strong class="tit_txt">[단독] 이만희 "이재명·박원순, 친일 교회에 잘 보이려고"…분노의 주장</strong>,
#  <strong class="tit_txt">쿠팡 美 공세 속 공정위 조사 길어져…인기상품 가로채기 조준(종합)</strong>,
#  <strong class="tit_txt">“커피값 2000원→5000원 됐다”...가격 오르는데 기분 좋게 먹는 ‘코스피 연동 커피’, 뭐길래</strong>,
#  <strong class="tit_txt">[김동원의 이코노믹스] AI 패권으로 부활하는 미국…한국, ‘AI 전환 로드맵’ 구축을</strong>,
#  <strong class="tit_txt">출산율로 지방소멸 해결? 축소사회 맞는 도시 재설계하자 [김태경의 시선]</strong>,
#  <strong class="tit_txt">[강현철의 뉴스 솎아내기] 토큰증권(STO)이 가져올 금융혁명</strong>,
#  <strong class="tit_txt">김 부장에게 정년 연장이 의미 있을까 [김상철의 경제 톺아보기]</strong>,
# ...

# %%
title[0].text
# Out:
# '李대통령 "재연장 생각했다면 오산"…양도세중과 유예종료 재강조(종합)'

# %%
title_list = []
for i in title:
    title_list.append(i.text)

# %%
import pandas as pd

# %%
data = pd.DataFrame(title_list,columns=["제목"])

# %%
data
# Out:
#                                                    제목
# 0              李대통령 "재연장 생각했다면 오산"…양도세중과 유예종료 재강조(종합)
# 1                  金 5000달러 눈앞, 銀 100달러 돌파… 동반 최고치 행진
# 2                [그린란드를 가다] 트럼프 야욕에 심란한데 대규모 정전까지(종합)
# 3                        주말에도 김병기 의혹 집중 수사...소환 시기 관심
# 4          4번의 민주정부 수립 함께한 ‘전략가’이자 ‘킹메이커’…이해찬 전 총리 별세
# 5                           '독기' 더 빼는 소주 [어떻게 생각하십니까]
# 6            [단독] 이만희 "이재명·박원순, 친일 교회에 잘 보이려고"…분노의 주장
# 7               쿠팡 美 공세 속 공정위 조사 길어져…인기상품 가로채기 조준(종합)
# 8   “커피값 2000원→5000원 됐다”...가격 오르는데 기분 좋게 먹는 ‘코스피 연...
# 9    [김동원의 이코노믹스] AI 패권으로 부활하는 미국…한국, ‘AI 전환 로드맵’ 구축을
# 10           출산율로 지방소멸 해결? 축소사회 맞는 도시 재설계하자 [김태경의 시선]
# 11                 [강현철의 뉴스 솎아내기] 토큰증권(STO)이 가져올 금융혁명
# 12                김 부장에게 정년 연장이 의미 있을까 [김상철의 경제 톺아보기]
# 13        [돈이 되는 화폐 이야기] 35. 버려진 돈이 만드는 새로운 가치의 순환 경제
# 14              국민의힘 “李대통령, 대국민 사과해야…지명 철회로 덮을 사안 아냐”
# 15                     “2% 성장은 희망사항”···학계 ‘L자형 침체’ 경고
# ...

# %%
title[0]["href"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 title[0]["href"]
#
# File ~\anaconda3\Lib\site-packages\bs4\element.py:1573, in Tag.__getitem__(self, key)
#    1570 def __getitem__(self, key):
#    1571     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1572     and throws an exception if it's not there."""
# -> 1573     return self.attrs[key]
#
# KeyError: 'href'

# %%
title
# Out:
# [<strong class="tit_txt">李대통령 "재연장 생각했다면 오산"…양도세중과 유예종료 재강조(종합)</strong>,
#  <strong class="tit_txt">金 5000달러 눈앞, 銀 100달러 돌파… 동반 최고치 행진</strong>,
#  <strong class="tit_txt">[그린란드를 가다] 트럼프 야욕에 심란한데 대규모 정전까지(종합)</strong>,
#  <strong class="tit_txt">주말에도 김병기 의혹 집중 수사...소환 시기 관심</strong>,
#  <strong class="tit_txt">4번의 민주정부 수립 함께한 ‘전략가’이자 ‘킹메이커’…이해찬 전 총리 별세</strong>,
#  <strong class="tit_txt">'독기' 더 빼는 소주 [어떻게 생각하십니까]</strong>,
#  <strong class="tit_txt">[단독] 이만희 "이재명·박원순, 친일 교회에 잘 보이려고"…분노의 주장</strong>,
#  <strong class="tit_txt">쿠팡 美 공세 속 공정위 조사 길어져…인기상품 가로채기 조준(종합)</strong>,
#  <strong class="tit_txt">“커피값 2000원→5000원 됐다”...가격 오르는데 기분 좋게 먹는 ‘코스피 연동 커피’, 뭐길래</strong>,
#  <strong class="tit_txt">[김동원의 이코노믹스] AI 패권으로 부활하는 미국…한국, ‘AI 전환 로드맵’ 구축을</strong>,
#  <strong class="tit_txt">출산율로 지방소멸 해결? 축소사회 맞는 도시 재설계하자 [김태경의 시선]</strong>,
#  <strong class="tit_txt">[강현철의 뉴스 솎아내기] 토큰증권(STO)이 가져올 금융혁명</strong>,
#  <strong class="tit_txt">김 부장에게 정년 연장이 의미 있을까 [김상철의 경제 톺아보기]</strong>,
# ...

# %%
for strong_tag in title:
    a_tag = strong_tag.find_parent("a")
    herf = a_tag.get("href")
    print(strong_tag.text, herf)
# Out:
# 李대통령 "재연장 생각했다면 오산"…양도세중과 유예종료 재강조(종합) https://v.daum.net/v/20260126005428718
# 金 5000달러 눈앞, 銀 100달러 돌파… 동반 최고치 행진 https://v.daum.net/v/20260126003230588
# [그린란드를 가다] 트럼프 야욕에 심란한데 대규모 정전까지(종합) https://v.daum.net/v/20260125235238940
# 주말에도 김병기 의혹 집중 수사...소환 시기 관심 https://v.daum.net/v/20260125232822808
# 4번의 민주정부 수립 함께한 ‘전략가’이자 ‘킹메이커’…이해찬 전 총리 별세 https://v.daum.net/v/20260125223104445
# '독기' 더 빼는 소주 [어떻게 생각하십니까] https://v.daum.net/v/20260125213142057
# [단독] 이만희 "이재명·박원순, 친일 교회에 잘 보이려고"…분노의 주장 https://v.daum.net/v/20260125201507164
# 쿠팡 美 공세 속 공정위 조사 길어져…인기상품 가로채기 조준(종합) https://v.daum.net/v/20260125195928917
# “커피값 2000원→5000원 됐다”...가격 오르는데 기분 좋게 먹는 ‘코스피 연동 커피’, 뭐길래 https://v.daum.net/v/20260125190523120
# [김동원의 이코노믹스] AI 패권으로 부활하는 미국…한국, ‘AI 전환 로드맵’ 구축을 https://v.daum.net/v/20260126002235543
# 출산율로 지방소멸 해결? 축소사회 맞는 도시 재설계하자 [김태경의 시선] https://v.daum.net/v/20260125190306068
# [강현철의 뉴스 솎아내기] 토큰증권(STO)이 가져올 금융혁명 https://v.daum.net/v/20260125170342455
# ...

# %%
req.get("https://www.melon.com/chart/index.htm")
# Out:
# <Response [406]>
